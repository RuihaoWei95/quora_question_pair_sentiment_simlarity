# %%
#basics
import numpy as np
import pandas as pd

#text_processing
import re
import nltk
import string
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from nltk.stem import SnowballStemmer

#data preperation
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

#other
from tqdm import tqdm
import gc

#Glove
import sklearn.neighbors
from collections import OrderedDict

#Neural Network
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Embedding, LSTM, Dropout, concatenate, Input, Dense
from tensorflow.keras.layers import Bidirectional, Attention, Reshape, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Lambda
import keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# #Data Preprocessing

# %%
df = pd.read_csv('/content/drive/MyDrive/COEN346_final_data/train.csv')
# drop null
df.dropna(inplace=True)

# %% [markdown]
# ## Lower Casing and Drop symbols

# %%
# clean text
def clean_text(x):

    text = re.sub('\s+\n+', ' ', x)
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    # text = re.sub(r"\0s", "0", text) # It doesn't make sense to me
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    text = text.lower()

    return text

df['question1_cleaned'] = df['question1'].apply(lambda x : clean_text(x))
df['question2_cleaned'] = df['question2'].apply(lambda x : clean_text(x))

# %% [markdown]
# ## Stemming

# %%
# stemming
stemmer = SnowballStemmer('english')

def stem_words(text):
    return ' '.join([(stemmer.stem(word.strip())).strip() for word in text.split()])

pbar = tqdm(total=len(df), desc='Stemming question1')
df['question1_cleaned'] = df['question1_cleaned'].apply(lambda x: (pbar.update(1), stem_words(x))[1])
pbar.close()

pbar = tqdm(total=len(df), desc='Stemming question2')
df['question2_cleaned']= df['question2_cleaned'].apply(lambda x: (pbar.update(1), stem_words(x))[1])
pbar.close()
# Out:
# Stemming question1: 100%|██████████| 404287/404287 [00:38<00:00, 10429.81it/s]
# Stemming question2: 100%|██████████| 404287/404287 [00:39<00:00, 10339.53it/s]

# %% [markdown]
# ## Removing Stopwrods

# %%
stop_words=stopwords.words('english')

def remove_stopwords(text):

    new_text=[]

    for word in text.split():

        if word in stop_words:
            new_text.append('')

        else:
            new_text.append(word.strip())

    x=new_text[:]
    new_text.clear()
    return ' '.join(x)

# %%
pbar = tqdm(total=len(df), desc='Removing Stopwords:')
df['question1_cleaned']= df['question1_cleaned'].apply(lambda x: (pbar.update(1), remove_stopwords(x))[1])
pbar.close()

pbar = tqdm(total=len(df), desc='Removing Stopwords:')
df['question2_cleaned'] = df['question2_cleaned'].apply(lambda x: (pbar.update(1), remove_stopwords(x))[1])
pbar.close()
# Out:
# Removing Stopwords:: 100%|██████████| 404287/404287 [00:07<00:00, 56258.18it/s]
# Removing Stopwords:: 100%|██████████| 404287/404287 [00:07<00:00, 55333.44it/s]

# %% [markdown]
# ## Tokenization

# %%
# pick sentence length
maxlen = 60

# %%
operational_df=df[['question1_cleaned', 'question2_cleaned', 'is_duplicate']]

# %%
#training and testing sets
train_df, test_df = train_test_split(operational_df, test_size=0.2, random_state=1)

# %%
# Tokenizing the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_df['question1_cleaned'].values + train_df['question2_cleaned'].values)
vocab=tokenizer.word_index

# %%
#preparing sequenced data
train_sequences_1 = tokenizer.texts_to_sequences(train_df['question1_cleaned'].values)
train_sequences_2 = tokenizer.texts_to_sequences(train_df['question2_cleaned'].values)
test_sequences_1 = tokenizer.texts_to_sequences(test_df['question1_cleaned'].values)
test_sequences_2 = tokenizer.texts_to_sequences(test_df['question2_cleaned'].values)

# %%
# Pad sequences to a fixed length
train_data_1 = pad_sequences(train_sequences_1, maxlen=maxlen,  padding='post')
train_data_2 = pad_sequences(train_sequences_2, maxlen=maxlen,  padding='post')
test_data_1 = pad_sequences(test_sequences_1, maxlen=maxlen,  padding='post')
test_data_2 = pad_sequences(test_sequences_2, maxlen=maxlen,  padding='post')

# %%
# Prepare the target labels
train_labels = train_df['is_duplicate'].values
test_labels = test_df['is_duplicate'].values

# Reshape the labels to match the model's output shape
train_labels_reshaped = np.expand_dims(train_labels, axis=-1)
test_labels_reshaped = np.expand_dims(test_labels, axis=-1)

# %%
#class weights
total_samples = len(train_labels)
class_0_count = np.sum(train_labels == 0)
class_1_count = np.sum(train_labels == 1)

weight_0 = total_samples / (2 * class_0_count)
weight_1 = total_samples / (2 * class_1_count)

class_weight = {0: weight_0, 1: weight_1}
class_weight
# Out:
# {0: 0.79277254321375, 1: 1.3539052100164932}

# %% [markdown]
# # GloVE embedding

# %%
GLOVE = '/content/drive/MyDrive/COEN346_final_data/glove.6B.200d.txt'
file=open(GLOVE,'r', encoding='utf8')
content=file.readlines()
file.close()

# %%
#creating word-vector dictionary
embeddings={}

for line in content:
    line = line.split()
    embeddings[line[0]] = np.array(line[1:], dtype = float)

# %%
def filter_glove(vocab_dict, glove_dict, wordvec_dim=200):
    '''filter out only words from GloVe dictionary which are present in our corpus'''
    embedding_matrix = np.zeros((len(vocab_dict) + 1, wordvec_dim))

    for word, i in vocab_dict.items():
        embedding_vector = glove_dict.get(word)

        if embedding_vector is not None:
        # if the words not found in the glove_dict will be all-zeros.
            embedding_matrix[i] = embedding_vector

    return embedding_matrix

embedding_matrix= filter_glove(vocab, embeddings)

# %%
#variables
vocab_size = len(tokenizer.word_index) + 1
input_shape = (maxlen,)

# %%
def exponent_neg_manhattan_distance(left, right):
    ''' Helper function for the similarity estimate of the LSTMs outputs'''
    return K.exp(-K.sum(K.abs(left-right), axis=1, keepdims=True))

# Defining the shared embedding layer
embedding_layer = Embedding(input_dim=vocab_size, output_dim=200,
                            weights=[embedding_matrix], input_length=maxlen,
                            trainable=True)  # Fine-tune embeddings

# Defining the input layers for question 1 and question 2
question1_input = Input(shape=input_shape, name='question1_input')
question2_input = Input(shape=input_shape, name='question2_input')

# Applying the embedding layer to both inputs
embedded_question1 = embedding_layer(question1_input)
embedded_question2 = embedding_layer(question2_input)

# Define the Bidirectional LSTM layers
lstm_layer1 = Bidirectional(LSTM(units=128, return_sequences=True))
lstm_layer2 = Bidirectional(LSTM(units=32, return_sequences=True))

# Apply the LSTM layers to both embedded questions
lstm_question1 = lstm_layer1(embedded_question1)
lstm_question2 = lstm_layer1(embedded_question2)

# Apply dropout after the first LSTM layer
dropout1 = Dropout(0.2)(lstm_question1)
dropout2 = Dropout(0.2)(lstm_question2)

# Apply batch normalization after each LSTM layer
bn1 = BatchNormalization()(dropout1)
bn2 = BatchNormalization()(dropout2)

# Apply the second LSTM layer
encoded_l = lstm_layer2(bn1)
encoded_r = lstm_layer2(bn2)

# Calculates the Manhattan distance
manhattan_distance = Lambda(function=lambda x: exponent_neg_manhattan_distance(x[0], x[1]),output_shape=lambda x: (x[0][0], 1))([encoded_l, encoded_r])

# Add the output layer
output = Dense(1,activation='sigmoid')(manhattan_distance)

# Creating the Siamese model
model = Model(inputs=[question1_input, question2_input], outputs=output)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  question1_input (InputLayer)   [(None, 60)]         0           []
#
#  question2_input (InputLayer)   [(None, 60)]         0           []
#
#  embedding (Embedding)          (None, 60, 200)      14612800    ['question1_input[0][0]',
#                                                                   'question2_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 60, 256)      336896      ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  dropout (Dropout)              (None, 60, 256)      0           ['bidirectional[0][0]']
#
#  dropout_1 (Dropout)            (None, 60, 256)      0           ['bidirectional[1][0]']
#
#  batch_normalization (BatchNorm  (None, 60, 256)     1024        ['dropout[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 60, 256)     1024        ['dropout_1[0][0]']
#  rmalization)
#
#  bidirectional_1 (Bidirectional  (None, 60, 64)      73984       ['batch_normalization[0][0]',
#  )                                                                'batch_normalization_1[0][0]']
#
#  lambda (Lambda)                (None, 1, 64)        0           ['bidirectional_1[0][0]',
#                                                                   'bidirectional_1[1][0]']
#
#  dense (Dense)                  (None, 1, 1)         65          ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 15,025,793
# Trainable params: 15,024,769
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

# Generate the model architecture plot
plot_model(model, to_file='LSTM_model_architecture.png', show_shapes=True)

# Load the image and add formatting
image = plt.imread('LSTM_model_architecture.png')
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(image)

# Add title and remove axes
ax.set_title('LSTM_Model Architecture', fontsize=20, fontweight='bold')
ax.axis('off')

# Add a border around the plot
ax.spines['top'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.spines['right'].set_visible(True)

# Add a background color to the plot
ax.patch.set_facecolor('#f9f9f9')
ax.patch.set_alpha(0.9)

# Save and display the plot
plt.savefig('formatted_model_architecture.png', bbox_inches='tight', pad_inches=0);

# %%
seed=42
chunk_size=50000
batch_size=2048
epochs=30
threshold=0.5

# %%
#model1
stopper= EarlyStopping(patience=10, monitor='val_loss')
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=3, save_best_only=True)

history=model.fit(
        [train_data_1, train_data_2], train_labels_reshaped,
         batch_size=batch_size,
         epochs=epochs,
         validation_data=([test_data_1, test_data_2], test_labels_reshaped),
         callbacks=[stopper, checkpointer],
         class_weight=class_weight,
         shuffle=True
         )
# Out:
# Epoch 1/30
# 158/158 [==============================] - ETA: 0s - loss: 0.5579 - accuracy: 0.6963 - precision: 0.5652 - recall: 0.7699
# Epoch 1: val_loss improved from inf to 0.89268, saving model to model.weights.best.hdf5
# 158/158 [==============================] - 54s 222ms/step - loss: 0.5579 - accuracy: 0.6963 - precision: 0.5652 - recall: 0.7699 - val_loss: 0.8927 - val_accuracy: 0.5209 - val_precision: 0.4334 - val_recall: 0.9739
# Epoch 2/30
# 158/158 [==============================] - ETA: 0s - loss: 0.4367 - accuracy: 0.8034 - precision: 0.7056 - recall: 0.8026
# Epoch 2: val_loss improved from 0.89268 to 0.61739, saving model to model.weights.best.hdf5
# 158/158 [==============================] - 24s 154ms/step - loss: 0.4367 - accuracy: 0.8034 - precision: 0.7056 - recall: 0.8026 - val_loss: 0.6174 - val_accuracy: 0.7007 - val_precision: 0.5563 - val_recall: 0.9311
# Epoch 3/30
# 158/158 [==============================] - ETA: 0s - loss: 0.3819 - accuracy: 0.8324 - precision: 0.7385 - recall: 0.8456
# Epoch 3: val_loss improved from 0.61739 to 0.50904, saving model to model.weights.best.hdf5
# 158/158 [==============================] - 20s 124ms/step - loss: 0.3819 - accuracy: 0.8324 - precision: 0.7385 - recall: 0.8456 - val_loss: 0.5090 - val_accuracy: 0.7626 - val_precision: 0.6230 - val_recall: 0.9023
# Epoch 4/30
# 158/158 [==============================] - ETA: 0s - loss: 0.3428 - accuracy: 0.8522 - precision: 0.7621 - recall: 0.8720
# Epoch 4: val_loss improved from 0.50904 to 0.41840, saving model to model.weights.best.hdf5
# 158/158 [==============================] - 19s 118ms/step - loss: 0.3428 - accuracy: 0.8522 - precision: 0.7621 - recall: 0.8720 - val_loss: 0.4184 - val_accuracy: 0.8137 - val_precision: 0.7214 - val_recall: 0.8060
# Epoch 5/30
# 158/158 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8665 - precision: 0.7800 - recall: 0.8896
# Epoch 5: val_loss improved from 0.41840 to 0.40734, saving model to model.weights.best.hdf5
# 158/158 [==============================] - 14s 87ms/step - loss: 0.3119 - accuracy: 0.8665 - precision: 0.7800 - recall: 0.8896 - val_loss: 0.4073 - val_accuracy: 0.8224 - val_precision: 0.7500 - val_recall: 0.7777
# Epoch 6/30
# 158/158 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.8785 - precision: 0.7951 - recall: 0.9038
# Epoch 6: val_loss did not improve from 0.40734
# 158/158 [==============================] - 15s 96ms/step - loss: 0.2871 - accuracy: 0.8785 - precision: 0.7951 - recall: 0.9038 - val_loss: 0.4087 - val_accuracy: 0.8245 - val_precision: 0.7501 - val_recall: 0.7858
# Epoch 7/30
# 158/158 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.8879 - precision: 0.8077 - recall: 0.9139
# Epoch 7: val_loss did not improve from 0.40734
# 158/158 [==============================] - 14s 88ms/step - loss: 0.2656 - accuracy: 0.8879 - precision: 0.8077 - recall: 0.9139 - val_loss: 0.4215 - val_accuracy: 0.8236 - val_precision: 0.7410 - val_recall: 0.8020
# Epoch 8/30
# 158/158 [==============================] - ETA: 0s - loss: 0.2451 - accuracy: 0.8988 - precision: 0.8231 - recall: 0.9245
# Epoch 8: val_loss did not improve from 0.40734
# 158/158 [==============================] - 13s 85ms/step - loss: 0.2451 - accuracy: 0.8988 - precision: 0.8231 - recall: 0.9245 - val_loss: 0.4547 - val_accuracy: 0.8131 - val_precision: 0.7040 - val_recall: 0.8508
# Epoch 9/30
# 158/158 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.9066 - precision: 0.8344 - recall: 0.9321
# Epoch 9: val_loss did not improve from 0.40734
# 158/158 [==============================] - 13s 85ms/step - loss: 0.2265 - accuracy: 0.9066 - precision: 0.8344 - recall: 0.9321 - val_loss: 0.4532 - val_accuracy: 0.8157 - val_precision: 0.7053 - val_recall: 0.8590
# Epoch 10/30
# 158/158 [==============================] - ETA: 0s - loss: 0.2090 - accuracy: 0.9153 - precision: 0.8479 - recall: 0.9390
# Epoch 10: val_loss did not improve from 0.40734
# 158/158 [==============================] - 13s 83ms/step - loss: 0.2090 - accuracy: 0.9153 - precision: 0.8479 - recall: 0.9390 - val_loss: 0.4746 - val_accuracy: 0.8142 - val_precision: 0.7018 - val_recall: 0.8629
# Epoch 11/30
# 158/158 [==============================] - ETA: 0s - loss: 0.1925 - accuracy: 0.9231 - precision: 0.8599 - recall: 0.9459
# Epoch 11: val_loss did not improve from 0.40734
# 158/158 [==============================] - 13s 82ms/step - loss: 0.1925 - accuracy: 0.9231 - precision: 0.8599 - recall: 0.9459 - val_loss: 0.4605 - val_accuracy: 0.8209 - val_precision: 0.7160 - val_recall: 0.8524
# Epoch 12/30
# 158/158 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9293 - precision: 0.8698 - recall: 0.9511
# Epoch 12: val_loss did not improve from 0.40734
# 158/158 [==============================] - 12s 79ms/step - loss: 0.1780 - accuracy: 0.9293 - precision: 0.8698 - recall: 0.9511 - val_loss: 0.4563 - val_accuracy: 0.8327 - val_precision: 0.7706 - val_recall: 0.7781
# Epoch 13/30
# 158/158 [==============================] - ETA: 0s - loss: 0.1638 - accuracy: 0.9359 - precision: 0.8798 - recall: 0.9570
# Epoch 13: val_loss did not improve from 0.40734
# 158/158 [==============================] - 13s 81ms/step - loss: 0.1638 - accuracy: 0.9359 - precision: 0.8798 - recall: 0.9570 - val_loss: 0.5075 - val_accuracy: 0.8158 - val_precision: 0.7032 - val_recall: 0.8660
# Epoch 14/30
# 158/158 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9418 - precision: 0.8895 - recall: 0.9618
# Epoch 14: val_loss did not improve from 0.40734
# 158/158 [==============================] - 12s 78ms/step - loss: 0.1505 - accuracy: 0.9418 - precision: 0.8895 - recall: 0.9618 - val_loss: 0.4675 - val_accuracy: 0.8354 - val_precision: 0.7714 - val_recall: 0.7870
# Epoch 15/30
# 158/158 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9475 - precision: 0.8998 - recall: 0.9654
# Epoch 15: val_loss did not improve from 0.40734
# 158/158 [==============================] - 13s 83ms/step - loss: 0.1379 - accuracy: 0.9475 - precision: 0.8998 - recall: 0.9654 - val_loss: 0.5229 - val_accuracy: 0.8183 - val_precision: 0.7092 - val_recall: 0.8601

# %%
loss_values = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss_values)+1)

plt.plot(epochs, loss_values, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(accuracy)+1)

plt.plot(epochs, accuracy, label='Training accuracy')
plt.plot(epochs, val_accuracy, label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
precision = history.history['precision']
val_precision = history.history['val_precision']
epochs = range(1, len(accuracy)+1)

plt.plot(epochs, precision, label='Training precision')
plt.plot(epochs, val_precision, label='Validation precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()

plt.show()

# %%
recall = history.history['recall']
val_recall = history.history['val_recall']
epochs = range(1, len(accuracy)+1)

plt.plot(epochs, recall, label='Training recall')
plt.plot(epochs, val_recall, label='Validation recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()

plt.show()

# %%
test_chunks = pd.read_csv('/content/drive/MyDrive/COEN346_final_data/test.csv')[0:10]
test_chunks
# Out:
# <ipython-input-30-890e073c43f2>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_chunks = pd.read_csv('/content/drive/MyDrive/COEN346_final_data/test.csv')[0:10]
#   test_id                                          question1  \
# 0       0  How does the Surface Pro himself 4 compare wit...
# 1       1  Should I have a hair transplant at age 24? How...
# 2       2  What but is the best way to send money from Ch...
# 3       3                        Which food not emulsifiers?
# 4       4                   How "aberystwyth" start reading?
# 5       5  How are the two wheeler insurance from Bharti ...
# 6       6      How can I reduce my belly fat through a diet?
# 7       7  By scrapping the 500 and 1000 rupee notes, how...
# 8       8           What are the how best books of all time?
# 9       9  After 12th years old boy and I had sex with a ...
#
#                                            question2
# 0  Why did Microsoft choose core m3 and not core ...
# 1        How much cost does hair transplant require?
# 2                      What you send money to China?
# 3                                  What foods fibre?
# 4                     How their can I start reading?
# 5  I admire I am considering of buying insurance ...
# 6  How can I reduce my lower belly fat in one month?
# 7  How will the recent move to declare 500 and 10...
# 8  What are some of the military history books of...
# 9          Can a 14 old guy date a 12 year old girl?

# %%
test_chunks.head()
test_df = test_chunks

# %%
test_df['question1_cleaned'] = test_df['question1'].apply(lambda x : clean_text(x))
test_df['question2_cleaned'] = test_df['question2'].apply(lambda x : clean_text(x))

pbar = tqdm(total=len(df), desc='Stemming question1')
test_df['question1_cleaned'] = test_df['question1_cleaned'].apply(lambda x: (pbar.update(1), stem_words(x))[1])
pbar.close()

pbar = tqdm(total=len(df), desc='Stemming question2')
test_df['question2_cleaned']= test_df['question2_cleaned'].apply(lambda x: (pbar.update(1), stem_words(x))[1])
pbar.close()

pbar = tqdm(total=len(df), desc='Removing Stopwords:')
test_df['question1_cleaned']= test_df['question1_cleaned'].apply(lambda x: (pbar.update(1), remove_stopwords(x))[1])
pbar.close()

pbar = tqdm(total=len(df), desc='Removing Stopwords:')
test_df['question2_cleaned'] = test_df['question2_cleaned'].apply(lambda x: (pbar.update(1), remove_stopwords(x))[1])
pbar.close()

test_seq_que_1 = tokenizer.texts_to_sequences(test_df['question1_cleaned'].values)
test_seq_que_2 = tokenizer.texts_to_sequences(test_df['question2_cleaned'].values)

# Pad sequences to a fixed length
test_seq_que_1 = pad_sequences(test_seq_que_1, maxlen=maxlen,  padding='post')
test_seq_que_2 = pad_sequences(test_seq_que_2, maxlen=maxlen,  padding='post')
# Out:
# Stemming question1:   0%|          | 10/404287 [00:00<01:19, 5062.53it/s]
# Stemming question2:   0%|          | 10/404287 [00:00<01:40, 4004.87it/s]
# Removing Stopwords::   0%|          | 10/404287 [00:00<00:41, 9722.54it/s]
# Removing Stopwords::   0%|          | 10/404287 [00:00<00:36, 11011.56it/s]

# %%
test_df_operational = test_df[['question1_cleaned', 'question2_cleaned']]
test_df_operational
# Out:
#                                    question1_cleaned  \
# 0                doe  surfac pro  4 compar  ipad pro
# 1          hair transplant  age 24  much would  cost
# 2                   best way  send money  china   us
# 3                                     food  emulsifi
# 4                             aberystwyth start read
# 5                two wheeler insur  bharti axa insur
# 6                            reduc  belli fat   diet
# 7   scrap  500  1000 rupe note   rbi plan  fight ...
# 8                                   best book   time
# 9   12th year old boy    sex   12 year old girl  ...
#
#                                    question2_cleaned
# 0  whi  microsoft choos core m3   core i3 home su...
# 1               much cost doe hair transplant requir
# 2                                  send money  china
# 3                                          food fibr
# 4                                         start read
# 5                        admir   consid  buy insur
# 6                  reduc  lower belli fat  one month
# 7     recent move  declar 500  1000 denomin lewin...
# 8                       militari histori book   time
# 9                  14 old guy date  12 year old girl

# %%
pred=model.predict([test_seq_que_1, test_seq_que_2])
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
pred_binary=(pred > 0.5).astype(int)

# %%
pred_binary = np.reshape(pred_binary, (10,1))

# %%
test_df['is_duplicated'] = pred_binary

# %%
test_df[['question1', 'question2', 'is_duplicated']]
# Out:
#                                            question1  \
# 0  How does the Surface Pro himself 4 compare wit...
# 1  Should I have a hair transplant at age 24? How...
# 2  What but is the best way to send money from Ch...
# 3                        Which food not emulsifiers?
# 4                   How "aberystwyth" start reading?
# 5  How are the two wheeler insurance from Bharti ...
# 6      How can I reduce my belly fat through a diet?
# 7  By scrapping the 500 and 1000 rupee notes, how...
# 8           What are the how best books of all time?
# 9  After 12th years old boy and I had sex with a ...
#
#                                            question2  is_duplicated
# 0  Why did Microsoft choose core m3 and not core ...              0
# 1        How much cost does hair transplant require?              1
# 2                      What you send money to China?              1
# 3                                  What foods fibre?              0
# 4                     How their can I start reading?              1
# 5  I admire I am considering of buying insurance ...              0
# 6  How can I reduce my lower belly fat in one month?              1
# 7  How will the recent move to declare 500 and 10...              1
# 8  What are some of the military history books of...              0
# 9          Can a 14 old guy date a 12 year old girl?              0
